# %% [markdown]
# ## Introduction
#
# The following notebook will use the Foursquare API to

# %% [markdown]
# ## Table of Contents
#
# 1. <a href="#item1">IBM New York Steakhouse Analysis</a>
# 2. <a href="#item2">IBM Chicago Steakhouse Analysis</a>

# %% [markdown]
# ### Import necessary Libraries

# %%
import requests # library to handle requests
import pandas as pd # library for data analsysis
import numpy as np # library to handle data in a vectorized manner
import random # library for random number generation

# !conda install -c conda-forge geopy --yes 
from geopy.geocoders import Nominatim # module to convert an address into latitude and longitude values

# libraries for displaying images
from IPython.display import Image 
from IPython.core.display import HTML 
    
# tranforming json file into a pandas dataframe library
from pandas.io.json import json_normalize

# !conda install -c conda-forge folium=0.5.0 --yes
import folium # plotting library

print('Folium installed')
print('Libraries imported.')
# Out:
# WARNING conda.base.context:use_only_tar_bz2(632): Conda is constrained to only using the old .tar.bz2 file format because you have conda-build installed, and it is <3.18.3.  Update or remove conda-build to get smaller downloads and faster extractions.
# Collecting package metadata (repodata.json): done
# Solving environment: failed
#
# PackagesNotFoundError: The following packages are not available from current channels:
#
#   - anaconda/linux-64::grpcio==1.16.1=py36hf8bcb03_1 -> openssl[version='>=1.1.1,<1.1.2.0a0']
#
# Current channels:
#
#   - https://conda.anaconda.org/conda-forge/linux-64
#   - https://conda.anaconda.org/conda-forge/noarch
#   - https://repo.anaconda.com/pkgs/main/linux-64
#   - https://repo.anaconda.com/pkgs/main/noarch
#   - https://repo.anaconda.com/pkgs/r/linux-64
#   - https://repo.anaconda.com/pkgs/r/noarch
#
# To search for alternate channels that may provide the conda package you're
# looking for, navigate to
#
#     https://anaconda.org
#
# and use the search bar at the top of the page.
#
#
# WARNING conda.base.context:use_only_tar_bz2(632): Conda is constrained to only using the old .tar.bz2 file format because you have conda-build installed, and it is <3.18.3.  Update or remove conda-build to get smaller downloads and faster extractions.
# Collecting package metadata (repodata.json): done
# Solving environment: failed
#
# PackagesNotFoundError: The following packages are not available from current channels:
#
#   - anaconda/linux-64::grpcio==1.16.1=py36hf8bcb03_1 -> openssl[version='>=1.1.1,<1.1.2.0a0']
#
# Current channels:
#
#   - https://conda.anaconda.org/conda-forge/linux-64
#   - https://conda.anaconda.org/conda-forge/noarch
#   - https://repo.anaconda.com/pkgs/main/linux-64
#   - https://repo.anaconda.com/pkgs/main/noarch
#   - https://repo.anaconda.com/pkgs/r/linux-64
#   - https://repo.anaconda.com/pkgs/r/noarch
#
# To search for alternate channels that may provide the conda package you're
# looking for, navigate to
#
#     https://anaconda.org
#
# and use the search bar at the top of the page.
#
#
# Folium installed
# Libraries imported.

# %% [markdown]
# ### Define Foursquare Credentials and Version

# %% [markdown]
# ##### Make sure that you have created a Foursquare developer account and have your credentials handy

# %%
CLIENT_ID = 'QW5U3IWJUNZAH0YWQZVNM3LHFKFW03M5NFKZP3ORYOYNHOX0' # your Foursquare ID
CLIENT_SECRET = 'URERCR0DVK4GXATBG2GWDOLSM42XYYRAB2HTE5LP1SJ3OSR1' # your Foursquare Secret
VERSION = '20180604'
LIMIT = 30
print('Your credentails:')
print('CLIENT_ID: ' + CLIENT_ID)
print('CLIENT_SECRET:' + CLIENT_SECRET)
# Out:
# Your credentails:
# CLIENT_ID: QW5U3IWJUNZAH0YWQZVNM3LHFKFW03M5NFKZP3ORYOYNHOX0
# CLIENT_SECRET:URERCR0DVK4GXATBG2GWDOLSM42XYYRAB2HTE5LP1SJ3OSR1

# %% [markdown]
# #### Let's assume that we are working at IBM NY. We will use Nominatim to convert IBM's New York address to its latitude and longitude coordinates.

# %% [markdown]
# In order to define an instance of the geocoder, we need to define a user_agent. We will name our agent <em>foursquare_agent</em>, as shown below.

# %%
address = '590 Madison Avenue, New York, NY'

geolocator = Nominatim(user_agent="foursquare_agent")
location = geolocator.geocode(address)
latitude = location.latitude
longitude = location.longitude
print(latitude, longitude)
# Out:
# 40.76215745 -73.9730331430771

# %% [markdown]
# <a id="item1"></a>

# %% [markdown]
# ## 1. Explore IBM New York's Local Steakhouse Selection
# > `https://api.foursquare.com/v2/venues/`**search**`?client_id=`**CLIENT_ID**`&client_secret=`**CLIENT_SECRET**`&ll=`**LATITUDE**`,`**LONGITUDE**`&v=`**VERSION**`&query=`**QUERY**`&radius=`**RADIUS**`&limit=`**LIMIT**

# %% [markdown]
# #### Now, let's assume that we have an important business meeting coming up, and would like to dine our clients at a steakhouse. Let's define a query to search for a steakhouse that is within 1000 metres from IBM NY.

# %%
search_query = 'steakhouse'
radius = 1000
print(query + '...OK!')
# Out:
# steakhouse...OK!

# %% [markdown]
# #### Define the corresponding URL

# %%
url = 'https://api.foursquare.com/v2/venues/search?client_id={}&client_secret={}&ll={},{}&v={}&query={}&radius={}&limit={}'.format(CLIENT_ID, CLIENT_SECRET, latitude, longitude, VERSION, search_query, radius, LIMIT)
url
# Out:
# 'https://api.foursquare.com/v2/venues/search?client_id=QW5U3IWJUNZAH0YWQZVNM3LHFKFW03M5NFKZP3ORYOYNHOX0&client_secret=URERCR0DVK4GXATBG2GWDOLSM42XYYRAB2HTE5LP1SJ3OSR1&ll=40.76215745,-73.9730331430771&v=20180604&query=steakhouse&radius=1000&limit=30'

# %% [markdown]
# #### Send the GET Request and examine the results

# %%
results = requests.get(url).json()
results
# Out:
# {'meta': {'code': 200, 'requestId': '5d212f6b8ad62e002c17c959'},
#  'response': {'venues': [{'id': '4b0c24fef964a520be3723e3',
#     'name': "Del Frisco's Double Eagle Steakhouse",
#     'location': {'address': '1221 Avenue of the Americas',
#      'crossStreet': 'at W 49th St',
#      'lat': 40.7594099,
#      'lng': -73.98222,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.7594099,
#        'lng': -73.98222}],
#      'distance': 832,
#      'postalCode': '10020',
#      'cc': 'US',
#      'city': 'New York',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['1221 Avenue of the Americas (at W 49th St)',
#       'New York, NY 10020',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d1cc941735',
#       'name': 'Steakhouse',
#       'pluralName': 'Steakhouses',
#       'shortName': 'Steakhouse',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/steakhouse_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1562455915',
#     'hasPerk': False},
#    {'id': '5a2148d3a8eb607c633e9f86',
#     'name': 'Nusr-Et Steakhouse',
#     'location': {'address': '60 W 53rd St',
#      'lat': 40.76142871873711,
#      'lng': -73.97860999896865,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.76142871873711,
#        'lng': -73.97860999896865}],
#      'distance': 477,
#      'postalCode': '10019',
#      'cc': 'US',
#      'city': 'New York',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['60 W 53rd St',
#       'New York, NY 10019',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d1cc941735',
#       'name': 'Steakhouse',
#       'pluralName': 'Steakhouses',
#       'shortName': 'Steakhouse',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/steakhouse_',
#        'suffix': '.png'},
#       'primary': True}],
#     'venuePage': {'id': '470471004'},
#     'referralId': 'v-1562455915',
#     'hasPerk': False},
#    {'id': '444ceab2f964a52084321fe3',
#     'name': 'Gallaghers Steakhouse',
#     'location': {'address': '228 W 52nd St',
#      'crossStreet': 'btwn Broadway & 8th Ave',
#      'lat': 40.76291113670059,
#      'lng': -73.98375655189533,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.76291113670059,
#        'lng': -73.98375655189533}],
#      'distance': 908,
#      'postalCode': '10019',
#      'cc': 'US',
#      'city': 'New York',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['228 W 52nd St (btwn Broadway & 8th Ave)',
#       'New York, NY 10019',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d1cc941735',
#       'name': 'Steakhouse',
#       'pluralName': 'Steakhouses',
#       'shortName': 'Steakhouse',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/steakhouse_',
#        'suffix': '.png'},
#       'primary': True}],
#     'venuePage': {'id': '79950054'},
#     'referralId': 'v-1562455915',
#     'hasPerk': False},
#    {'id': '4bdee9930d69b713760866d3',
#     'name': "Wolfgang's Steakhouse",
#     'location': {'address': '200 E 54th St',
#      'crossStreet': 'at 3rd Ave',
#      'lat': 40.758080406494436,
#      'lng': -73.96854899886894,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.758080406494436,
#        'lng': -73.96854899886894}],
#      'distance': 590,
#      'postalCode': '10022',
#      'cc': 'US',
#      'city': 'New York',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['200 E 54th St (at 3rd Ave)',
#       'New York, NY 10022',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d1cc941735',
#       'name': 'Steakhouse',
#       'pluralName': 'Steakhouses',
#       'shortName': 'Steakhouse',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/steakhouse_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1562455915',
#     'hasPerk': False},
#    {'id': '4b0e0b45f964a520545423e3',
#     'name': "Morton's The Steakhouse",
#     'location': {'address': '551 5th Ave',
#      'crossStreet': 'at E 45th St',
#      'lat': 40.7554075,
#      'lng': -73.9789116,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.7554075,
#        'lng': -73.9789116}],
#      'distance': 900,
#      'postalCode': '10176',
#      'cc': 'US',
#      'city': 'New York',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['551 5th Ave (at E 45th St)',
#       'New York, NY 10176',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d1cc941735',
#       'name': 'Steakhouse',
#       'pluralName': 'Steakhouses',
#       'shortName': 'Steakhouse',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/steakhouse_',
#        'suffix': '.png'},
#       'primary': True}],
#     'delivery': {'id': '304488',
#      'url': 'https://www.seamless.com/menu/mortons-the-steakhouse-551-5th-ave-new-york/304488?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=304488',
#      'provider': {'name': 'seamless',
#       'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#        'sizes': [40, 50],
#        'name': '/delivery_provider_seamless_20180129.png'}}},
#     'referralId': 'v-1562455915',
#     'hasPerk': False},
#    {'id': '4ad122f0f964a520f8dc20e3',
#     'name': 'Club A Steakhouse',
#     'location': {'address': '240 E 58th St',
#      'crossStreet': 'btwn 2nd & 3rd Ave.',
#      'lat': 40.76023556580318,
#      'lng': -73.96540359079097,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.76023556580318,
#        'lng': -73.96540359079097}],
#      'distance': 677,
#      'postalCode': '10022',
#      'cc': 'US',
#      'city': 'New York',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['240 E 58th St (btwn 2nd & 3rd Ave.)',
#       'New York, NY 10022',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d1cc941735',
#       'name': 'Steakhouse',
#       'pluralName': 'Steakhouses',
#       'shortName': 'Steakhouse',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/steakhouse_',
#        'suffix': '.png'},
#       'primary': True}],
#     'venuePage': {'id': '45903982'},
#     'referralId': 'v-1562455915',
#     'hasPerk': False},
#    {'id': '5b3e9929ca18ea002c8ba1f2',
#     'name': "Ben & Jack's Steakhouse",
#     'location': {'address': '219 E 44th St',
#      'lat': 40.75141415877203,
#      'lng': -73.97275223750951,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.75141415877203,
#        'lng': -73.97275223750951}],
#      'distance': 1196,
#      'postalCode': '10017',
#      'cc': 'US',
#      'city': 'New York',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['219 E 44th St',
#       'New York, NY 10017',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d1cc941735',
#       'name': 'Steakhouse',
#       'pluralName': 'Steakhouses',
#       'shortName': 'Steakhouse',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/steakhouse_',
#        'suffix': '.png'},
#       'primary': True}],
#     'delivery': {'id': '882263',
#      'url': 'https://www.seamless.com/menu/ben--jacks-steakhouse-219-e-44th-st-new-york/882263?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=882263',
#      'provider': {'name': 'seamless',
#       'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#        'sizes': [40, 50],
#        'name': '/delivery_provider_seamless_20180129.png'}}},
#     'referralId': 'v-1562455915',
#     'hasPerk': False},
#    {'id': '525d7bde498e3a406f590b1d',
#     'name': "Davio's North Italian Steakhouse",
#     'location': {'address': '447 Lexington Ave',
#      'crossStreet': '45th Street',
#      'lat': 40.753233339315564,
#      'lng': -73.97477368607031,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.753233339315564,
#        'lng': -73.97477368607031}],
#      'distance': 1004,
#      'postalCode': '10017',
#      'cc': 'US',
#      'city': 'New York',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['447 Lexington Ave (45th Street)',
#       'New York, NY 10017',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d110941735',
#       'name': 'Italian Restaurant',
#       'pluralName': 'Italian Restaurants',
#       'shortName': 'Italian',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/italian_',
#        'suffix': '.png'},
#       'primary': True}],
#     'venuePage': {'id': '74919433'},
#     'referralId': 'v-1562455915',
#     'hasPerk': False},
#    {'id': '55e8d4ba498e70c2f53bd493',
#     'name': "Wolfgang's Steakhouse Boutique",
#     'location': {'address': '16 E 46th St',
#      'lat': 40.75569509836387,
#      'lng': -73.9779484703546,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.75569509836387,
#        'lng': -73.9779484703546}],
#      'distance': 830,
#      'postalCode': '10017',
#      'cc': 'US',
#      'city': 'New York',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['16 E 46th St',
#       'New York, NY 10017',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d1cc941735',
#       'name': 'Steakhouse',
#       'pluralName': 'Steakhouses',
#       'shortName': 'Steakhouse',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/steakhouse_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1562455915',
#     'hasPerk': False},
#    {'id': '545cd793498ec095fd8b6251',
#     'name': "Mastro's Steakhouse",
#     'location': {'address': '1285 Avenue of the Americas',
#      'crossStreet': 'at W 52nd St',
#      'lat': 40.7610374,
#      'lng': -73.9802619,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.7610374,
#        'lng': -73.9802619}],
#      'distance': 622,
#      'postalCode': '10019',
#      'cc': 'US',
#      'city': 'New York',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['1285 Avenue of the Americas (at W 52nd St)',
#       'New York, NY 10019',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d1cc941735',
#       'name': 'Steakhouse',
#       'pluralName': 'Steakhouses',
#       'shortName': 'Steakhouse',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/steakhouse_',
#        'suffix': '.png'},
#       'primary': True}],
#     'venuePage': {'id': '104862490'},
#     'referralId': 'v-1562455915',
#     'hasPerk': False},
#    {'id': '525da4dc498eb92d634abb7a',
#     'name': "Ruth's Chris Steak House",
#     'location': {'address': '148 West 51st Street',
#      'crossStreet': 'btwn 6th & 7th Ave',
#      'lat': 40.7614312,
#      'lng': -73.982328,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.7614312,
#        'lng': -73.982328}],
#      'distance': 787,
#      'postalCode': '10019',
#      'cc': 'US',
#      'city': 'New York',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['148 West 51st Street (btwn 6th & 7th Ave)',
#       'New York, NY 10019',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d1cc941735',
#       'name': 'Steakhouse',
#       'pluralName': 'Steakhouses',
#       'shortName': 'Steakhouse',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/steakhouse_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1562455915',
#     'hasPerk': False},
#    {'id': '4b395e3df964a520745b25e3',
#     'name': "Bobby Van's Steakhouse",
#     'location': {'address': '131 E 54th St',
#      'crossStreet': 'at Lexington Ave',
#      'lat': 40.7592819749193,
#      'lng': -73.97100553415832,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.7592819749193,
#        'lng': -73.97100553415832}],
#      'distance': 362,
#      'postalCode': '10022',
#      'cc': 'US',
#      'city': 'New York',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['131 E 54th St (at Lexington Ave)',
#       'New York, NY 10022',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d1cc941735',
#       'name': 'Steakhouse',
#       'pluralName': 'Steakhouses',
#       'shortName': 'Steakhouse',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/steakhouse_',
#        'suffix': '.png'},
#       'primary': True}],
#     'delivery': {'id': '783889',
#      'url': 'https://www.seamless.com/menu/bobby-vans-steakhouse-131-e-54th-st-new-york/783889?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=783889',
#      'provider': {'name': 'seamless',
#       'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#        'sizes': [40, 50],
#        'name': '/delivery_provider_seamless_20180129.png'}}},
#     'venuePage': {'id': '75562668'},
#     'referralId': 'v-1562455915',
#     'hasPerk': False},
#    {'id': '3fd66200f964a5207ee71ee3',
#     'name': 'Sparks Steak House',
#     'location': {'address': '210 E 46th St',
#      'crossStreet': 'btwn 2nd & 3rd Ave.',
#      'lat': 40.753150244877446,
#      'lng': -73.97202587725334,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.753150244877446,
#        'lng': -73.97202587725334}],
#      'distance': 1006,
#      'postalCode': '10017',
#      'cc': 'US',
#      'city': 'New York',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['210 E 46th St (btwn 2nd & 3rd Ave.)',
#       'New York, NY 10017',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d1cc941735',
#       'name': 'Steakhouse',
#       'pluralName': 'Steakhouses',
#       'shortName': 'Steakhouse',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/steakhouse_',
#        'suffix': '.png'},
#       'primary': True}],
#     'venuePage': {'id': '94068536'},
#     'referralId': 'v-1562455915',
#     'hasPerk': False},
#    {'id': '5a42e3ff4acb1973fb8c2531',
#     'name': 'Tuscany Steakhouse',
#     'location': {'address': '117 W 58th St',
#      'lat': 40.765608,
#      'lng': -73.977552,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.765608,
#        'lng': -73.977552}],
#      'distance': 541,
#      'postalCode': '10019',
#      'cc': 'US',
#      'city': 'New York',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['117 W 58th St',
#       'New York, NY 10019',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d1cc941735',
#       'name': 'Steakhouse',
#       'pluralName': 'Steakhouses',
#       'shortName': 'Steakhouse',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/steakhouse_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1562455915',
#     'hasPerk': False},
#    {'id': '569ab104498e3954b38cb67e',
#     'name': 'Empire Steak House -  50th Street',
#     'location': {'address': '151 E 50th St',
#      'crossStreet': '3rd & Lexington Ave',
#      'lat': 40.75615,
#      'lng': -73.97127,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.75615,
#        'lng': -73.97127}],
#      'distance': 685,
#      'postalCode': '10022',
#      'cc': 'US',
#      'city': 'New York',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['151 E 50th St (3rd & Lexington Ave)',
#       'New York, NY 10022',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d1cc941735',
#       'name': 'Steakhouse',
#       'pluralName': 'Steakhouses',
#       'shortName': 'Steakhouse',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/steakhouse_',
#        'suffix': '.png'},
#       'primary': True}],
#     'delivery': {'id': '350267',
#      'url': 'https://www.seamless.com/menu/empire-steak-house-151-e-50th-street-new-york/350267?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=350267',
#      'provider': {'name': 'seamless',
#       'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#        'sizes': [40, 50],
#        'name': '/delivery_provider_seamless_20180129.png'}}},
#     'venuePage': {'id': '152430003'},
#     'referralId': 'v-1562455915',
#     'hasPerk': False},
#    {'id': '52c8598c498ee3bb717e1116',
#     'name': 'Angus Club Steakhouse',
#     'location': {'address': '135 E 55th Street',
#      'lat': 40.75947978233424,
#      'lng': -73.96983423245736,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.75947978233424,
#        'lng': -73.96983423245736}],
#      'distance': 401,
#      'postalCode': '10022',
#      'cc': 'US',
#      'city': 'New York',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['135 E 55th Street',
#       'New York, NY 10022',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d1cc941735',
#       'name': 'Steakhouse',
#       'pluralName': 'Steakhouses',
#       'shortName': 'Steakhouse',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/steakhouse_',
#        'suffix': '.png'},
#       'primary': True}],
#     'venuePage': {'id': '85857738'},
#     'referralId': 'v-1562455915',
#     'hasPerk': False},
#    {'id': '538f3942498e429b5c9cf9d9',
#     'name': '212 Steakhouse',
#     'location': {'address': '316 East 53rd St',
#      'crossStreet': '2nd Avenue',
#      'lat': 40.75645238297343,
#      'lng': -73.9665316312116,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.75645238297343,
#        'lng': -73.9665316312116}],
#      'distance': 838,
#      'postalCode': '10022',
#      'cc': 'US',
#      'neighborhood': 'Midtown East, New York, NY',
#      'city': 'New York',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['316 East 53rd St (2nd Avenue)',
#       'New York, NY 10022',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d1cc941735',
#       'name': 'Steakhouse',
#       'pluralName': 'Steakhouses',
#       'shortName': 'Steakhouse',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/steakhouse_',
#        'suffix': '.png'},
#       'primary': True}],
#     'delivery': {'id': '297193',
#      'url': 'https://www.seamless.com/menu/212-steakhouse-316-e-53rd-st-new-york/297193?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=297193',
#      'provider': {'name': 'seamless',
#       'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#        'sizes': [40, 50],
#        'name': '/delivery_provider_seamless_20180129.png'}}},
#     'venuePage': {'id': '90739845'},
#     'referralId': 'v-1562455915',
#     'hasPerk': False},
#    {'id': '52d811e8498e1907266de867',
#     'name': 'Empire Steak House - 54th Street',
#     'location': {'address': '237 W 54th St',
#      'crossStreet': 'Btwn Broadway & 8th Avenue',
#      'lat': 40.76453190000001,
#      'lng': -73.983043,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.76453190000001,
#        'lng': -73.983043}],
#      'distance': 884,
#      'postalCode': '10019',
#      'cc': 'US',
#      'city': 'New York',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['237 W 54th St (Btwn Broadway & 8th Avenue)',
#       'New York, NY 10019',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d1cc941735',
#       'name': 'Steakhouse',
#       'pluralName': 'Steakhouses',
#       'shortName': 'Steakhouse',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/steakhouse_',
#        'suffix': '.png'},
#       'primary': True}],
#     'delivery': {'id': '292310',
#      'url': 'https://www.seamless.com/menu/empire-steak-house--237-w-54th-st-new-york/292310?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=292310',
#      'provider': {'name': 'seamless',
#       'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#        'sizes': [40, 50],
#        'name': '/delivery_provider_seamless_20180129.png'}}},
#     'venuePage': {'id': '76348848'},
#     'referralId': 'v-1562455915',
#     'hasPerk': False},
#    {'id': '3fd66200f964a52070e71ee3',
#     'name': "Michael Jordan's The Steak House N.Y.C.",
#     'location': {'address': '23 Vanderbilt Avenue',
#      'crossStreet': 'Grand Central Terminal',
#      'lat': 40.7530806,
#      'lng': -73.9772353,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.7530806,
#        'lng': -73.9772353}],
#      'distance': 1070,
#      'postalCode': '10017',
#      'cc': 'US',
#      'city': 'New York',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['23 Vanderbilt Avenue (Grand Central Terminal)',
#       'New York, NY 10017',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d1cc941735',
#       'name': 'Steakhouse',
#       'pluralName': 'Steakhouses',
#       'shortName': 'Steakhouse',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/steakhouse_',
#        'suffix': '.png'},
#       'primary': True}],
#     'venuePage': {'id': '55852679'},
#     'referralId': 'v-1562455915',
#     'hasPerk': False},
#    {'id': '51e7310c498e639ed27062b1',
#     'name': 'Quality Italian',
#     'location': {'address': '57 W 57th St',
#      'crossStreet': 'at 6th Ave',
#      'lat': 40.76447598357648,
#      'lng': -73.97703230787566,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.76447598357648,
#        'lng': -73.97703230787566}],
#      'distance': 424,
#      'postalCode': '10019',
#      'cc': 'US',
#      'city': 'New York',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['57 W 57th St (at 6th Ave)',
#       'New York, NY 10019',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d110941735',
#       'name': 'Italian Restaurant',
#       'pluralName': 'Italian Restaurants',
#       'shortName': 'Italian',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/italian_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1562455915',
#     'hasPerk': False},
#    {'id': '5a552b012e26807b1a71ae3e',
#     'name': 'Primal Cut Steakhouse',
#     'location': {'address': '333 E 60th St',
#      'lat': 40.76075691731533,
#      'lng': -73.96235331896604,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.76075691731533,
#        'lng': -73.96235331896604}],
#      'distance': 913,
#      'postalCode': '10022',
#      'cc': 'US',
#      'city': 'New York',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['333 E 60th St',
#       'New York, NY 10022',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d1cc941735',
#       'name': 'Steakhouse',
#       'pluralName': 'Steakhouses',
#       'shortName': 'Steakhouse',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/steakhouse_',
#        'suffix': '.png'},
#       'primary': True}],
#     'venuePage': {'id': '473412993'},
#     'referralId': 'v-1562455915',
#     'hasPerk': False},
#    {'id': '3fd66200f964a52053ea1ee3',
#     'name': 'Monkey Bar',
#     'location': {'address': '60 E 54th St',
#      'crossStreet': 'btwn Madison & Park Ave.',
#      'lat': 40.76015032843378,
#      'lng': -73.97314575291665,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.76015032843378,
#        'lng': -73.97314575291665}],
#      'distance': 223,
#      'postalCode': '10022',
#      'cc': 'US',
#      'city': 'New York',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['60 E 54th St (btwn Madison & Park Ave.)',
#       'New York, NY 10022',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d157941735',
#       'name': 'New American Restaurant',
#       'pluralName': 'New American Restaurants',
#       'shortName': 'New American',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/newamerican_',
#        'suffix': '.png'},
#       'primary': True}],
#     'venuePage': {'id': '80672409'},
#     'referralId': 'v-1562455915',
#     'hasPerk': False},
#    {'id': '4ae9bca7f964a520f9b521e3',
#     'name': 'Wolf & Lamb Steakhouse',
#     'location': {'address': '10 E 48th St',
#      'crossStreet': 'between 5th and Madison',
#      'lat': 40.756738,
#      'lng': -73.976988,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.756738,
#        'lng': -73.976988}],
#      'distance': 689,
#      'postalCode': '10017',
#      'cc': 'US',
#      'city': 'New York',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['10 E 48th St (between 5th and Madison)',
#       'New York, NY 10017',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d1cc941735',
#       'name': 'Steakhouse',
#       'pluralName': 'Steakhouses',
#       'shortName': 'Steakhouse',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/steakhouse_',
#        'suffix': '.png'},
#       'primary': True}],
#     'delivery': {'id': '65282',
#      'url': 'https://www.seamless.com/menu/wolf--lamb-steakhouse-10-e-48th-st-new-york/65282?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=65282',
#      'provider': {'name': 'seamless',
#       'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#        'sizes': [40, 50],
#        'name': '/delivery_provider_seamless_20180129.png'}}},
#     'venuePage': {'id': '136896341'},
#     'referralId': 'v-1562455915',
#     'hasPerk': False},
#    {'id': '3fd66200f964a52041eb1ee3',
#     'name': 'Smith & Wollensky',
#     'location': {'address': '797 3rd Ave',
#      'crossStreet': 'at E 49th St',
#      'lat': 40.75524817570486,
#      'lng': -73.97117774711768,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.75524817570486,
#        'lng': -73.97117774711768}],
#      'distance': 784,
#      'postalCode': '10017',
#      'cc': 'US',
#      'city': 'New York',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['797 3rd Ave (at E 49th St)',
#       'New York, NY 10017',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d1cc941735',
#       'name': 'Steakhouse',
#       'pluralName': 'Steakhouses',
#       'shortName': 'Steakhouse',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/steakhouse_',
#        'suffix': '.png'},
#       'primary': True}],
#     'delivery': {'id': '1175255',
#      'url': 'https://www.seamless.com/menu/smith--wollensky-201-e-49th-st-new-york/1175255?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=1175255',
#      'provider': {'name': 'seamless',
#       'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#        'sizes': [40, 50],
#        'name': '/delivery_provider_seamless_20180129.png'}}},
#     'venuePage': {'id': '52970266'},
#     'referralId': 'v-1562455915',
#     'hasPerk': False},
#    {'id': '562bca39498ee3e1c93aa037',
#     'name': 'Four Cuts Steakhouse',
#     'location': {'address': '1076 1st Ave',
#      'lat': 40.75940567002905,
#      'lng': -73.9620816274485,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.75940567002905,
#        'lng': -73.9620816274485}],
#      'distance': 972,
#      'postalCode': '10022',
#      'cc': 'US',
#      'city': 'New York',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['1076 1st Ave',
#       'New York, NY 10022',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d1cc941735',
#       'name': 'Steakhouse',
#       'pluralName': 'Steakhouses',
#       'shortName': 'Steakhouse',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/steakhouse_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1562455915',
#     'hasPerk': False},
#    {'id': '5218058311d2681bb2a63d6c',
#     'name': 'Prime 333 Steakhouse',
#     'location': {'address': '333 E 60th St',
#      'lat': 40.760578,
#      'lng': -73.962322,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.760578,
#        'lng': -73.962322}],
#      'distance': 920,
#      'postalCode': '10022',
#      'cc': 'US',
#      'city': 'New York',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['333 E 60th St',
#       'New York, NY 10022',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d14e941735',
#       'name': 'American Restaurant',
#       'pluralName': 'American Restaurants',
#       'shortName': 'American',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1562455915',
#     'hasPerk': False},
#    {'id': '4b01f350f964a520c84622e3',
#     'name': "Bobby Van's",
#     'location': {'address': '230 Park Ave.',
#      'crossStreet': '46th St.',
#      'lat': 40.754948271785146,
#      'lng': -73.97546451151206,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.754948271785146,
#        'lng': -73.97546451151206}],
#      'distance': 828,
#      'postalCode': '10169',
#      'cc': 'US',
#      'city': 'New York',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['230 Park Ave. (46th St.)',
#       'New York, NY 10169',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d1cc941735',
#       'name': 'Steakhouse',
#       'pluralName': 'Steakhouses',
#       'shortName': 'Steakhouse',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/steakhouse_',
#        'suffix': '.png'},
#       'primary': True}],
#     'venuePage': {'id': '129144665'},
#     'referralId': 'v-1562455915',
#     'hasPerk': False},
#    {'id': '45814450f964a520613f1fe3',
#     'name': 'BLT Steak',
#     'location': {'address': '106 E 57th St',
#      'crossStreet': 'at Park Ave',
#      'lat': 40.761496793927165,
#      'lng': -73.97019700936767,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.761496793927165,
#        'lng': -73.97019700936767}],
#      'distance': 250,
#      'postalCode': '10022',
#      'cc': 'US',
#      'city': 'New York',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['106 E 57th St (at Park Ave)',
#       'New York, NY 10022',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d1cc941735',
#       'name': 'Steakhouse',
#       'pluralName': 'Steakhouses',
#       'shortName': 'Steakhouse',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/steakhouse_',
#        'suffix': '.png'},
#       'primary': True}],
#     'venuePage': {'id': '34928921'},
#     'referralId': 'v-1562455915',
#     'hasPerk': False},
#    {'id': '4b0c6b59f964a520d63c23e3',
#     'name': "Bobby Van's",
#     'location': {'address': '135 W 50th St',
#      'crossStreet': 'btw 6th & 7th Ave',
#      'lat': 40.7609268711439,
#      'lng': -73.98282719266979,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.7609268711439,
#        'lng': -73.98282719266979}],
#      'distance': 837,
#      'postalCode': '10020',
#      'cc': 'US',
#      'city': 'New York',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['135 W 50th St (btw 6th & 7th Ave)',
#       'New York, NY 10020',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d1cc941735',
#       'name': 'Steakhouse',
#       'pluralName': 'Steakhouses',
#       'shortName': 'Steakhouse',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/steakhouse_',
#        'suffix': '.png'},
#       'primary': True}],
#     'delivery': {'id': '429787',
#      'url': 'https://www.seamless.com/menu/bobby-vans-grill-west-50th-135-w-50th-st-new-york/429787?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=429787',
#      'provider': {'name': 'seamless',
#       'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#        'sizes': [40, 50],
#        'name': '/delivery_provider_seamless_20180129.png'}}},
#     'venuePage': {'id': '79599122'},
#     'referralId': 'v-1562455915',
#     'hasPerk': False},
#    {'id': '4b5f457df964a52037b129e3',
#     'name': "Tad's Steaks",
#     'location': {'address': '761 7th Ave',
#      'crossStreet': 'at 47th St.',
#      'lat': 40.760966197983244,
#      'lng': -73.98299392156794,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.760966197983244,
#        'lng': -73.98299392156794}],
#      'distance': 850,
#      'postalCode': '10019',
#      'cc': 'US',
#      'neighborhood': 'Theater District',
#      'city': 'New York',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['761 7th Ave (at 47th St.)',
#       'New York, NY 10019',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d1cc941735',
#       'name': 'Steakhouse',
#       'pluralName': 'Steakhouses',
#       'shortName': 'Steakhouse',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/steakhouse_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1562455915',
#     'hasPerk': False}]}}

# %% [markdown]
# #### Get relevant part of JSON and transform it into a *pandas* dataframe

# %%
# assign relevant part of JSON to venues
venues = results['response']['venues']

# tranform venues into a dataframe
dataframe = json_normalize(venues)
dataframe.head()
# Out:
#                                           categories delivery.id  \
# 0  [{'id': '4bf58dd8d48988d1cc941735', 'name': 'S...         NaN
# 1  [{'id': '4bf58dd8d48988d1cc941735', 'name': 'S...         NaN
# 2  [{'id': '4bf58dd8d48988d1cc941735', 'name': 'S...         NaN
# 3  [{'id': '4bf58dd8d48988d1cc941735', 'name': 'S...         NaN
# 4  [{'id': '4bf58dd8d48988d1cc941735', 'name': 'S...      304488
#
#                 delivery.provider.icon.name  \
# 0                                       NaN
# 1                                       NaN
# 2                                       NaN
# 3                                       NaN
# 4  /delivery_provider_seamless_20180129.png
#
#               delivery.provider.icon.prefix delivery.provider.icon.sizes  \
# 0                                       NaN                          NaN
# 1                                       NaN                          NaN
# 2                                       NaN                          NaN
# 3                                       NaN                          NaN
# 4  https://fastly.4sqi.net/img/general/cap/                     [40, 50]
#
#   delivery.provider.name                                       delivery.url  \
# 0                    NaN                                                NaN
# 1                    NaN                                                NaN
# 2                    NaN                                                NaN
# 3                    NaN                                                NaN
# 4               seamless  https://www.seamless.com/menu/mortons-the-stea...
#
#    hasPerk                        id             location.address  ...  \
# 0    False  4b0c24fef964a520be3723e3  1221 Avenue of the Americas  ...
# 1    False  5a2148d3a8eb607c633e9f86                 60 W 53rd St  ...
# 2    False  444ceab2f964a52084321fe3                228 W 52nd St  ...
# 3    False  4bdee9930d69b713760866d3                200 E 54th St  ...
# 4    False  4b0e0b45f964a520545423e3                  551 5th Ave  ...
#
#                            location.formattedAddress  \
# 0  [1221 Avenue of the Americas (at W 49th St), N...
# 1  [60 W 53rd St, New York, NY 10019, United States]
# 2  [228 W 52nd St (btwn Broadway & 8th Ave), New ...
# 3  [200 E 54th St (at 3rd Ave), New York, NY 1002...
# 4  [551 5th Ave (at E 45th St), New York, NY 1017...
#
#                              location.labeledLatLngs location.lat  \
# 0  [{'label': 'display', 'lat': 40.7594099, 'lng'...    40.759410
# 1  [{'label': 'display', 'lat': 40.76142871873711...    40.761429
# 2  [{'label': 'display', 'lat': 40.76291113670059...    40.762911
# 3  [{'label': 'display', 'lat': 40.75808040649443...    40.758080
# 4  [{'label': 'display', 'lat': 40.7554075, 'lng'...    40.755407
#
#   location.lng  location.neighborhood location.postalCode location.state  \
# 0   -73.982220                    NaN               10020             NY
# 1   -73.978610                    NaN               10019             NY
# 2   -73.983757                    NaN               10019             NY
# 3   -73.968549                    NaN               10022             NY
# 4   -73.978912                    NaN               10176             NY
#
#                                    name    referralId venuePage.id
# 0  Del Frisco's Double Eagle Steakhouse  v-1562455915          NaN
# 1                    Nusr-Et Steakhouse  v-1562455915    470471004
# 2                 Gallaghers Steakhouse  v-1562455915     79950054
# 3                 Wolfgang's Steakhouse  v-1562455915          NaN
# 4               Morton's The Steakhouse  v-1562455915          NaN
#
# [5 rows x 25 columns]

# %% [markdown]
# #### Define information of interest and filter dataframe

# %%
# keep only columns that include venue name, and anything that is associated with location
filtered_columns = ['name', 'categories'] + [col for col in dataframe.columns if col.startswith('location.')] + ['id']
dataframe_filtered = dataframe.loc[:, filtered_columns]

# function that extracts the category of the venue
def get_category_type(row):
    try:
        categories_list = row['categories']
    except:
        categories_list = row['venue.categories']
        
    if len(categories_list) == 0:
        return None
    else:
        return categories_list[0]['name']

# filter the category for each row
dataframe_filtered['categories'] = dataframe_filtered.apply(get_category_type, axis=1)

# clean column names by keeping only last term
dataframe_filtered.columns = [column.split('.')[-1] for column in dataframe_filtered.columns]

dataframe_filtered.head()
# Out:
#                                    name  categories  \
# 0  Del Frisco's Double Eagle Steakhouse  Steakhouse
# 1                    Nusr-Et Steakhouse  Steakhouse
# 2                 Gallaghers Steakhouse  Steakhouse
# 3                 Wolfgang's Steakhouse  Steakhouse
# 4               Morton's The Steakhouse  Steakhouse
#
#                        address  cc      city        country  \
# 0  1221 Avenue of the Americas  US  New York  United States
# 1                 60 W 53rd St  US  New York  United States
# 2                228 W 52nd St  US  New York  United States
# 3                200 E 54th St  US  New York  United States
# 4                  551 5th Ave  US  New York  United States
#
#                crossStreet  distance  \
# 0             at W 49th St       832
# 1                      NaN       477
# 2  btwn Broadway & 8th Ave       908
# 3               at 3rd Ave       590
# 4             at E 45th St       900
#
#                                     formattedAddress  \
# 0  [1221 Avenue of the Americas (at W 49th St), N...
# 1  [60 W 53rd St, New York, NY 10019, United States]
# 2  [228 W 52nd St (btwn Broadway & 8th Ave), New ...
# 3  [200 E 54th St (at 3rd Ave), New York, NY 1002...
# 4  [551 5th Ave (at E 45th St), New York, NY 1017...
#
#                                       labeledLatLngs        lat        lng  \
# 0  [{'label': 'display', 'lat': 40.7594099, 'lng'...  40.759410 -73.982220
# 1  [{'label': 'display', 'lat': 40.76142871873711...  40.761429 -73.978610
# 2  [{'label': 'display', 'lat': 40.76291113670059...  40.762911 -73.983757
# 3  [{'label': 'display', 'lat': 40.75808040649443...  40.758080 -73.968549
# 4  [{'label': 'display', 'lat': 40.7554075, 'lng'...  40.755407 -73.978912
#
#   neighborhood postalCode state                        id
# 0          NaN      10020    NY  4b0c24fef964a520be3723e3
# 1          NaN      10019    NY  5a2148d3a8eb607c633e9f86
# 2          NaN      10019    NY  444ceab2f964a52084321fe3
# 3          NaN      10022    NY  4bdee9930d69b713760866d3
# 4          NaN      10176    NY  4b0e0b45f964a520545423e3

# %% [markdown]
# #### Let's visualize the steakhouses that are nearby

# %%
dataframe_filtered.name
# Out:
# 0        Del Frisco's Double Eagle Steakhouse
# 1                          Nusr-Et Steakhouse
# 2                       Gallaghers Steakhouse
# 3                       Wolfgang's Steakhouse
# 4                     Morton's The Steakhouse
# 5                           Club A Steakhouse
# 6                     Ben & Jack's Steakhouse
# 7            Davio's North Italian Steakhouse
# 8              Wolfgang's Steakhouse Boutique
# 9                         Mastro's Steakhouse
# 10                   Ruth's Chris Steak House
# 11                     Bobby Van's Steakhouse
# 12                         Sparks Steak House
# 13                         Tuscany Steakhouse
# 14          Empire Steak House -  50th Street
# 15                      Angus Club Steakhouse
# 16                             212 Steakhouse
# 17           Empire Steak House - 54th Street
# 18    Michael Jordan's The Steak House N.Y.C.
# 19                            Quality Italian
# 20                      Primal Cut Steakhouse
# 21                                 Monkey Bar
# 22                     Wolf & Lamb Steakhouse
# 23                          Smith & Wollensky
# 24                       Four Cuts Steakhouse
# 25                       Prime 333 Steakhouse
# 26                                Bobby Van's
# 27                                  BLT Steak
# 28                                Bobby Van's
# 29                               Tad's Steaks
# Name: name, dtype: object

# %% [markdown]
# #### Now let's use Folium to create an interactive map highlighting IBM NY and the nearest steakhouses

# %%
newyork_map = folium.Map(location=[latitude, longitude], zoom_start=13) # generate map centred around IBM NY

# add a blue circle marker to represent the IBM New York
folium.features.CircleMarker(
    [latitude, longitude],
    radius=10,
    color='blue',
    popup='IBM NY',
    fill = True,
    fill_color = 'blue',
    fill_opacity = 0.6
).add_to(newyork_map)

# add the steakhouse restaurants as brown circle markers
for lat, lng, label in zip(dataframe_filtered.lat, dataframe_filtered.lng, dataframe_filtered.categories):
    folium.features.CircleMarker(
        [lat, lng],
        radius=5,
        color='black',
        popup=label,
        fill = True,
        fill_color='brown',
        fill_opacity=0.6
    ).add_to(newyork_map)

# display map
newyork_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# <a id="item2"></a>

# %% [markdown]
# ## 2. Explore IBM Chicago's Local Steakhouse Selection
# > `https://api.foursquare.com/v2/venues/`**search**`?client_id=`**CLIENT_ID**`&client_secret=`**CLIENT_SECRET**`&ll=`**LATITUDE**`,`**LONGITUDE**`&v=`**VERSION**`&query=`**QUERY**`&radius=`**RADIUS**`&limit=`**LIMIT**

# %% [markdown]
# ### A. Following the steps we used earlier, we will again use the Nominatim tool to convert IBM Chicago's address into its latitude and longitude components.

# %%
address = '71 S Wacker Dr, Chicago, IL'

geolocator = Nominatim(user_agent="foursquare_agent")
location = geolocator.geocode(address)
latitude = location.latitude
longitude = location.longitude
print(latitude, longitude)
# Out:
# 41.8811007 -87.6360332229134

# %% [markdown]
# #### Now, let's assume that we have an important business meeting coming up, and would like to dine our clients at a steakhouse. Let's define a query to search for a steakhouse that is within 1000 metres from IBM NY.

# %%
search_query = 'steakhouse'
radius = 1000
print(query + '...OK!')
# Out:
# steakhouse...OK!

# %% [markdown]
# #### Define the corresponding URL

# %%
url = 'https://api.foursquare.com/v2/venues/search?client_id={}&client_secret={}&ll={},{}&v={}&query={}&radius={}&limit={}'.format(CLIENT_ID, CLIENT_SECRET, latitude, longitude, VERSION, search_query, radius, LIMIT)
url
# Out:
# 'https://api.foursquare.com/v2/venues/search?client_id=QW5U3IWJUNZAH0YWQZVNM3LHFKFW03M5NFKZP3ORYOYNHOX0&client_secret=URERCR0DVK4GXATBG2GWDOLSM42XYYRAB2HTE5LP1SJ3OSR1&ll=41.8811007,-87.6360332229134&v=20180604&query=steakhouse&radius=1000&limit=30'

# %% [markdown]
# #### Send the GET Request and examine the results

# %%
results = requests.get(url).json()
results
# Out:
# {'meta': {'code': 200, 'requestId': '5d212fb30d2be7002c72f54c'},
#  'response': {'venues': [{'id': '41fd7500f964a520501f1fe3',
#     'name': "Harry Caray's Italian Steakhouse",
#     'location': {'address': '33 W Kinzie St',
#      'crossStreet': 'at Dearborn St',
#      'lat': 41.889071055749454,
#      'lng': -87.6294590845703,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 41.889071055749454,
#        'lng': -87.6294590845703}],
#      'distance': 1041,
#      'postalCode': '60654',
#      'cc': 'US',
#      'city': 'Chicago',
#      'state': 'IL',
#      'country': 'United States',
#      'formattedAddress': ['33 W Kinzie St (at Dearborn St)',
#       'Chicago, IL 60654',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d1cc941735',
#       'name': 'Steakhouse',
#       'pluralName': 'Steakhouses',
#       'shortName': 'Steakhouse',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/steakhouse_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1562455987',
#     'hasPerk': False},
#    {'id': '4c924f7f238c6dcb6467c755',
#     'name': 'Chicago Cut Steakhouse',
#     'location': {'address': '300 N LaSalle Dr',
#      'crossStreet': 'at Carroll Ave',
#      'lat': 41.88797208145695,
#      'lng': -87.63290941161584,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 41.88797208145695,
#        'lng': -87.63290941161584}],
#      'distance': 807,
#      'postalCode': '60654',
#      'cc': 'US',
#      'city': 'Chicago',
#      'state': 'IL',
#      'country': 'United States',
#      'formattedAddress': ['300 N LaSalle Dr (at Carroll Ave)',
#       'Chicago, IL 60654',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d1cc941735',
#       'name': 'Steakhouse',
#       'pluralName': 'Steakhouses',
#       'shortName': 'Steakhouse',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/steakhouse_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1562455987',
#     'hasPerk': False},
#    {'id': '4b93e023f964a520c55634e3',
#     'name': "Ronny's Original Chicago Steak House",
#     'location': {'address': '100 W Randolph St',
#      'crossStreet': 'at Lake & Clark St',
#      'lat': 41.88573474519847,
#      'lng': -87.63119540641847,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 41.88573474519847,
#        'lng': -87.63119540641847}],
#      'distance': 653,
#      'postalCode': '60601',
#      'cc': 'US',
#      'city': 'Chicago',
#      'state': 'IL',
#      'country': 'United States',
#      'formattedAddress': ['100 W Randolph St (at Lake & Clark St)',
#       'Chicago, IL 60601',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d1cc941735',
#       'name': 'Steakhouse',
#       'pluralName': 'Steakhouses',
#       'shortName': 'Steakhouse',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/steakhouse_',
#        'suffix': '.png'},
#       'primary': True}],
#     'delivery': {'id': '768819',
#      'url': 'https://www.grubhub.com/restaurant/ronnys-steak-house-100-w-randolph-st-chicago/768819?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=768819',
#      'provider': {'name': 'grubhub',
#       'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#        'sizes': [40, 50],
#        'name': '/delivery_provider_grubhub_20180129.png'}}},
#     'referralId': 'v-1562455987',
#     'hasPerk': False},
#    {'id': '4b53b49cf964a5208ca827e3',
#     'name': "Ruth's Chris Steak House",
#     'location': {'address': '431 North Dearborn Street',
#      'lat': 41.8901981146158,
#      'lng': -87.62942612171173,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 41.8901981146158,
#        'lng': -87.62942612171173}],
#      'distance': 1151,
#      'postalCode': '60654',
#      'cc': 'US',
#      'city': 'Chicago',
#      'state': 'IL',
#      'country': 'United States',
#      'formattedAddress': ['431 North Dearborn Street',
#       'Chicago, IL 60654',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d1cc941735',
#       'name': 'Steakhouse',
#       'pluralName': 'Steakhouses',
#       'shortName': 'Steakhouse',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/steakhouse_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1562455987',
#     'hasPerk': False},
#    {'id': '4ae4fa72f964a520e29f21e3',
#     'name': 'Smith & Wollensky',
#     'location': {'address': '318 N State St',
#      'crossStreet': 'at Marina City',
#      'lat': 41.88757950530234,
#      'lng': -87.62824328593362,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 41.88757950530234,
#        'lng': -87.62824328593362}],
#      'distance': 967,
#      'postalCode': '60654',
#      'cc': 'US',
#      'city': 'Chicago',
#      'state': 'IL',
#      'country': 'United States',
#      'formattedAddress': ['318 N State St (at Marina City)',
#       'Chicago, IL 60654',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d1cc941735',
#       'name': 'Steakhouse',
#       'pluralName': 'Steakhouses',
#       'shortName': 'Steakhouse',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/steakhouse_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1562455987',
#     'hasPerk': False},
#    {'id': '4eebe5427ee5f45386c9d5b3',
#     'name': 'Steak house',
#     'location': {'address': '616 N. State Street',
#      'lat': 41.88876419441635,
#      'lng': -87.63018955267772,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 41.88876419441635,
#        'lng': -87.63018955267772}],
#      'distance': 980,
#      'postalCode': '60610',
#      'cc': 'US',
#      'city': 'Chicago',
#      'state': 'IL',
#      'country': 'United States',
#      'formattedAddress': ['616 N. State Street',
#       'Chicago, IL 60610',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d1cc941735',
#       'name': 'Steakhouse',
#       'pluralName': 'Steakhouses',
#       'shortName': 'Steakhouse',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/steakhouse_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1562455987',
#     'hasPerk': False},
#    {'id': '4cc0925a9ca854811c3fbd16',
#     'name': 'Mortons Restaurant Group, Inc.',
#     'location': {'address': '325 N La Salle Dr',
#      'lat': 41.888076825028385,
#      'lng': -87.63183782666428,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 41.888076825028385,
#        'lng': -87.63183782666428}],
#      'distance': 850,
#      'postalCode': '60654',
#      'cc': 'US',
#      'city': 'Chicago',
#      'state': 'IL',
#      'country': 'United States',
#      'formattedAddress': ['325 N La Salle Dr',
#       'Chicago, IL 60654',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d124941735',
#       'name': 'Office',
#       'pluralName': 'Offices',
#       'shortName': 'Office',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/default_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1562455987',
#     'hasPerk': False},
#    {'id': '4e4043ef81dc6ce0fac9d80b',
#     'name': 'Japanese Steak House & Sushi',
#     'location': {'address': '120 Jackson Blvd.',
#      'lat': 41.8786912,
#      'lng': -87.6260527,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 41.8786912,
#        'lng': -87.6260527}],
#      'distance': 869,
#      'cc': 'US',
#      'city': 'Chicago',
#      'state': 'IL',
#      'country': 'United States',
#      'formattedAddress': ['120 Jackson Blvd.',
#       'Chicago, IL',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d111941735',
#       'name': 'Japanese Restaurant',
#       'pluralName': 'Japanese Restaurants',
#       'shortName': 'Japanese',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/japanese_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1562455987',
#     'hasPerk': False},
#    {'id': '4de860131f6e9b53770c4625',
#     'name': "Refeal's Steak House",
#     'location': {'lat': 41.875565,
#      'lng': -87.624416,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 41.875565,
#        'lng': -87.624416}],
#      'distance': 1143,
#      'cc': 'US',
#      'city': 'Chicago',
#      'state': 'IL',
#      'country': 'United States',
#      'formattedAddress': ['Chicago, IL', 'United States']},
#     'categories': [{'id': '4bf58dd8d48988d14e941735',
#       'name': 'American Restaurant',
#       'pluralName': 'American Restaurants',
#       'shortName': 'American',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1562455987',
#     'hasPerk': False}]}}

# %% [markdown]
# #### Get relevant part of JSON and transform it into a *pandas* dataframe

# %%
# assign relevant part of JSON to venues
venues = results['response']['venues']

# tranform venues into a dataframe
dataframe = json_normalize(venues)
dataframe.head()
# Out:
#                                           categories delivery.id  \
# 0  [{'id': '4bf58dd8d48988d1cc941735', 'name': 'S...         NaN
# 1  [{'id': '4bf58dd8d48988d1cc941735', 'name': 'S...         NaN
# 2  [{'id': '4bf58dd8d48988d1cc941735', 'name': 'S...      768819
# 3  [{'id': '4bf58dd8d48988d1cc941735', 'name': 'S...         NaN
# 4  [{'id': '4bf58dd8d48988d1cc941735', 'name': 'S...         NaN
#
#                delivery.provider.icon.name  \
# 0                                      NaN
# 1                                      NaN
# 2  /delivery_provider_grubhub_20180129.png
# 3                                      NaN
# 4                                      NaN
#
#               delivery.provider.icon.prefix delivery.provider.icon.sizes  \
# 0                                       NaN                          NaN
# 1                                       NaN                          NaN
# 2  https://fastly.4sqi.net/img/general/cap/                     [40, 50]
# 3                                       NaN                          NaN
# 4                                       NaN                          NaN
#
#   delivery.provider.name                                       delivery.url  \
# 0                    NaN                                                NaN
# 1                    NaN                                                NaN
# 2                grubhub  https://www.grubhub.com/restaurant/ronnys-stea...
# 3                    NaN                                                NaN
# 4                    NaN                                                NaN
#
#    hasPerk                        id           location.address  ...  \
# 0    False  41fd7500f964a520501f1fe3             33 W Kinzie St  ...
# 1    False  4c924f7f238c6dcb6467c755           300 N LaSalle Dr  ...
# 2    False  4b93e023f964a520c55634e3          100 W Randolph St  ...
# 3    False  4b53b49cf964a5208ca827e3  431 North Dearborn Street  ...
# 4    False  4ae4fa72f964a520e29f21e3             318 N State St  ...
#
#   location.crossStreet location.distance  \
# 0       at Dearborn St              1041
# 1       at Carroll Ave               807
# 2   at Lake & Clark St               653
# 3                  NaN              1151
# 4       at Marina City               967
#
#                            location.formattedAddress  \
# 0  [33 W Kinzie St (at Dearborn St), Chicago, IL ...
# 1  [300 N LaSalle Dr (at Carroll Ave), Chicago, I...
# 2  [100 W Randolph St (at Lake & Clark St), Chica...
# 3  [431 North Dearborn Street, Chicago, IL 60654,...
# 4  [318 N State St (at Marina City), Chicago, IL ...
#
#                              location.labeledLatLngs  location.lat  \
# 0  [{'label': 'display', 'lat': 41.88907105574945...     41.889071
# 1  [{'label': 'display', 'lat': 41.88797208145695...     41.887972
# 2  [{'label': 'display', 'lat': 41.88573474519847...     41.885735
# 3  [{'label': 'display', 'lat': 41.8901981146158,...     41.890198
# 4  [{'label': 'display', 'lat': 41.88757950530234...     41.887580
#
#   location.lng location.postalCode  location.state  \
# 0   -87.629459               60654              IL
# 1   -87.632909               60654              IL
# 2   -87.631195               60601              IL
# 3   -87.629426               60654              IL
# 4   -87.628243               60654              IL
#
#                                    name    referralId
# 0      Harry Caray's Italian Steakhouse  v-1562455987
# 1                Chicago Cut Steakhouse  v-1562455987
# 2  Ronny's Original Chicago Steak House  v-1562455987
# 3              Ruth's Chris Steak House  v-1562455987
# 4                     Smith & Wollensky  v-1562455987
#
# [5 rows x 23 columns]

# %% [markdown]
# #### Define information of interest and filter dataframe

# %%
# keep only columns that include venue name, and anything that is associated with location
filtered_columns = ['name', 'categories'] + [col for col in dataframe.columns if col.startswith('location.')] + ['id']
dataframe_filtered = dataframe.loc[:, filtered_columns]

# function that extracts the category of the venue
def get_category_type(row):
    try:
        categories_list = row['categories']
    except:
        categories_list = row['venue.categories']
        
    if len(categories_list) == 0:
        return None
    else:
        return categories_list[0]['name']

# filter the category for each row
dataframe_filtered['categories'] = dataframe_filtered.apply(get_category_type, axis=1)

# clean column names by keeping only last term
dataframe_filtered.columns = [column.split('.')[-1] for column in dataframe_filtered.columns]

dataframe_filtered.head()
# Out:
#                                    name  categories  \
# 0      Harry Caray's Italian Steakhouse  Steakhouse
# 1                Chicago Cut Steakhouse  Steakhouse
# 2  Ronny's Original Chicago Steak House  Steakhouse
# 3              Ruth's Chris Steak House  Steakhouse
# 4                     Smith & Wollensky  Steakhouse
#
#                      address  cc     city        country         crossStreet  \
# 0             33 W Kinzie St  US  Chicago  United States      at Dearborn St
# 1           300 N LaSalle Dr  US  Chicago  United States      at Carroll Ave
# 2          100 W Randolph St  US  Chicago  United States  at Lake & Clark St
# 3  431 North Dearborn Street  US  Chicago  United States                 NaN
# 4             318 N State St  US  Chicago  United States      at Marina City
#
#    distance                                   formattedAddress  \
# 0      1041  [33 W Kinzie St (at Dearborn St), Chicago, IL ...
# 1       807  [300 N LaSalle Dr (at Carroll Ave), Chicago, I...
# 2       653  [100 W Randolph St (at Lake & Clark St), Chica...
# 3      1151  [431 North Dearborn Street, Chicago, IL 60654,...
# 4       967  [318 N State St (at Marina City), Chicago, IL ...
#
#                                       labeledLatLngs        lat        lng  \
# 0  [{'label': 'display', 'lat': 41.88907105574945...  41.889071 -87.629459
# 1  [{'label': 'display', 'lat': 41.88797208145695...  41.887972 -87.632909
# 2  [{'label': 'display', 'lat': 41.88573474519847...  41.885735 -87.631195
# 3  [{'label': 'display', 'lat': 41.8901981146158,...  41.890198 -87.629426
# 4  [{'label': 'display', 'lat': 41.88757950530234...  41.887580 -87.628243
#
#   postalCode state                        id
# 0      60654    IL  41fd7500f964a520501f1fe3
# 1      60654    IL  4c924f7f238c6dcb6467c755
# 2      60601    IL  4b93e023f964a520c55634e3
# 3      60654    IL  4b53b49cf964a5208ca827e3
# 4      60654    IL  4ae4fa72f964a520e29f21e3

# %% [markdown]
# #### Let's visualize the steakhouses that are nearby

# %%
dataframe_filtered.name
# Out:
# 0        Harry Caray's Italian Steakhouse
# 1                  Chicago Cut Steakhouse
# 2    Ronny's Original Chicago Steak House
# 3                Ruth's Chris Steak House
# 4                       Smith & Wollensky
# 5                             Steak house
# 6          Mortons Restaurant Group, Inc.
# 7            Japanese Steak House & Sushi
# 8                    Refeal's Steak House
# Name: name, dtype: object

# %% [markdown]
# #### Now let's use Folium to create an interactive map highlighting IBM Chicago and the nearest steakhouses

# %%
chicago_map = folium.Map(location=[latitude, longitude], zoom_start=13) # generate map centred around the IBM Chicago

# add a blue circle marker to represent the IBM Chicago
folium.features.CircleMarker(
    [latitude, longitude],
    radius=10,
    color='blue',
    popup='IBM NY',
    fill = True,
    fill_color = 'blue',
    fill_opacity = 0.6
).add_to(chicago_map)

# add the steakhouse restaurants as brown circle markers
for lat, lng, label in zip(dataframe_filtered.lat, dataframe_filtered.lng, dataframe_filtered.categories):
    folium.features.CircleMarker(
        [lat, lng],
        radius=5,
        color='black',
        popup=label,
        fill = True,
        fill_color='brown',
        fill_opacity=0.6
    ).add_to(chicago_map)

# display map
chicago_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>
